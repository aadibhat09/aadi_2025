# %% [markdown]
# ---
# layout: post
# title: "CS113 Open Coding Society Contributions and Retrospective"
# description: "My blog on CS113 objectives"
# permalink: /posts/cs113
# comments: true
# ---

# %% [markdown]
# ---
# title: CS113 Trimester Retrospective — NodCursor & Gamification
# date: 2026-05-31
# author: aadibhat09
# ---
#
# ## Overview
#
# This is a copy-paste ready retrospective for my CS113 trimester work. Every claim below points to evidence in the commit history so the post is auditable and easy to expand later.
#
# Primary focus this trimester: implementing the site-wide nodcursor accessibility feature, integrating head-tracking into gamification (nod-driven games), and helping with the CS Pathway calendar integration.
#
# ### What I worked on (short table)
#
# | Workstream | Short description |
# |---|---|
# | NodCursor & Preferences | Site-wide head-tracking cursor, calibration manager, persistence, Theme/Preferences integration |
# | Gamification (Nod Games) | Maze & Empathy player integration using head-tracking as input |
# | Calendar integration | Assisted CS Pathway calendar → student UI wiring and frontend polish |
#
# ## CS113 Objective Matrix
#
# Below I map course objectives to what I implemented and point to commits that demonstrate each objective. These links cite commits authored by `aadibhat09` in the local `pages-fork` repo (Mar–May 2026).
#
# | Objective | What I demonstrated | Evidence (commit links in pages-fork) |
# |---|---|---|
# | Data Structures | Modeled calibration objects, preferences objects, and game state (walls, levels) as structured objects rather than scattered primitives. | [36aed05c](https://github.com/aadibhat09/pages-fork/commit/36aed05cad471f32a97d80ea5b3f35c29ad3bdf8) (head-tracking prefs persist), [6e7dcee6](https://github.com/aadibhat09/pages-fork/commit/6e7dcee6e7168bc1f281475149302e310ae58e06) (nod game initial) |
# | Collections | Stored calibration captures, theme presets, and game-level wall lists; used arrays and maps to manage these collections. | [568d8a36](https://github.com/aadibhat09/pages-fork/commit/568d8a362a502844399f44cb2d382474dbf99705) (head tracking beta), [7e0cb65d](https://github.com/aadibhat09/pages-fork/commit/7e0cb65da7b34ea21ccaf8386b041d5fee1dd0eb) (NOD game complete) |
# | Lists / Queues | Ordered calibration capture flow and level progression in games (L1→L3). | [7301db2e](https://github.com/aadibhat09/pages-fork/commit/7301db2ef5626f85f0d35e7a13be798c4d9e9126) (calibration POST working), [6e7dcee6](https://github.com/aadibhat09/pages-fork/commit/6e7dcee6e7168bc1f281475149302e310ae58e06) (nod game initial) |
# | OOP / MVC | Single-responsibility classes for theme, translation, TTS, nodcursor calibration/controller, and game objects. | [36aed05c](https://github.com/aadibhat09/pages-fork/commit/36aed05cad471f32a97d80ea5b3f35c29ad3bdf8) (cross-page prefs), [568d8a36](https://github.com/aadibhat09/pages-fork/commit/568d8a362a502844399f44cb2d382474dbf99705) (dashboard beta) |
# | Algorithms | Head raw→viewport mapping, smoothing filter, blink-as-click detection, collision detection for maze, and exit detection. | [8e27b109](https://github.com/aadibhat09/pages-fork/commit/8e27b109c13dffbec8f5974fae21b2c324a6dbb3) (blink-to-click), [6e7dcee6](https://github.com/aadibhat09/pages-fork/commit/6e7dcee6e7168bc1f281475149302e310ae58e06) (game movement & collision) |
# | Version Control | Kept work in small, traceable commits during Mar–May 2026 for `pages-fork` development. | [05d19bf6](https://github.com/aadibhat09/pages-fork/commit/05d19bf689ca9aa787f45a15015c5e8c74974b11) (merge nod-game), [0722aea4](https://github.com/aadibhat09/pages-fork/commit/0722aea4336d624ae5182345020a77cfeb97bf19) (merge PR) |
#
# ### 1) NodCursor — Accessibility built as system
#
# What: A site-wide head-tracking cursor implemented as a small, SRP-driven module. The system includes calibration capture, smoothing, blink-to-click detection, an injected cursor UI element, persistence (local + optional backend), and an API surface via `window.SitePreferences`.
#
# Why it matters: This turns head movement into a first-class input method across the site without invasive changes to individual pages. The calibration manager keeps personalized mappings safe and reloadable per user.
#
# Key files and code (in this repo): `userpreferences.js`, `preferences.js` — search for `NodCursor`, `NodCursorController`, and `NodCursorCalibrationManager`.
#
# Representative commits and notes: pages-fork commits in Mar–May 2026 cited above (blink, calibration, preferences, merges).
#
# ### 2) Gamification — Nod-driven games
#
# What: I built `GameLevelNod` (maze) and adapted `EmpathyEpicPlayer` to work with head/mouse input. The maze uses wall arrays, collision detection, level progression, and a HUD with restart/score logic.
#
# Why it matters: It demonstrates a real gameplay loop that can be controlled by the accessibility feature — opening learning-by-play opportunities for students who rely on alternative input.
#
# Key files: `GameLevelNod` (MazeRenderer, MazePlayer, GameHUD), `EmpathyEpicPlayer`.
#
# ### 3) Calendar integration support
#
# What: Helped wire the CS Pathway calendar timeline into the student UI and assisted with styling and comment/notification flows so the calendar could act as a coordination layer between content and game launches.
#
# Representative commits: calendar and UI progress across Apr–May 2026: referenced above in the table.
#
# ### 4) Ethics & privacy
#
# Approach: Calibration and personal preferences default to local storage; backend save/load is optional and gated by login checks; the reset flow clears local storage keys. This minimizes inadvertent sharing of calibration metadata.
#
# ## Commit ledger (selected, Mar–May 2026)
#
# - pages-fork: [8232a3c2](https://github.com/aadibhat09/pages-fork/commit/8232a3c2c5fec1e9af6152f017c848e0898b58d7) — update agents md with calendar stuff and email in progress
# - pages-fork: [ea1763fa](https://github.com/aadibhat09/pages-fork/commit/ea1763fac56097df413b19a1176102493fdf755f) — add live markdown preview + author
# - pages-fork: [c0539b2c](https://github.com/aadibhat09/pages-fork/commit/c0539b2c062adcdaed9b9c6ce13c052f753a9463) — calendar updated for issues
# - pages-fork: [29caaceb](https://github.com/aadibhat09/pages-fork/commit/29caaceb91d78f7a7ba1354d922f3779d2ffb3a0) — finalize scss + calendar for frontend
# - pages-fork: [8b64ce4ac](https://github.com/aadibhat09/pages-fork/commit/8b64ce4ac5e020141ef0866fa120fecaf5219997) — attempt at calendar to game link
# - pages-fork: [8bcb15a96](https://github.com/aadibhat09/pages-fork/commit/8bcb15a96d530fcbb34168e9e0ac319ad11d890c) — integrate CS Pathway personal timeline
#
# - spring: [6b248322](https://github.com/aadibhat09/spring/commit/6b2483227ed70af106721b5f7240346ed45e0098) — update for emails backend (comment/email/calendar flows)
# - spring: [36bbf60f](https://github.com/aadibhat09/spring/commit/36bbf60fdbf3021113b9b9ed496e7ce0fa59c253) — calendar issues update with requested features
# - spring: [156b9d45](https://github.com/aadibhat09/spring/commit/156b9d45cd86189be876404530637da7d99881f0) — analytics admin additions / backend items
#
# ---
#
# If you'd like, I can:
#
# - Add screenshots and inline code excerpts to the post.
# - Replace the example commit selections with a granular per-objective search through the `open-Coding-Society/pages` repo (I can scan commits starting March 2026 and update links).
# - Commit this file into the repo, or open a PR where you want it shown.
#
# File created: retrospective/cs113-2026.md
